# %%
import json

# %%
with open('test copy.json', 'r') as file:
    data = json.load(file)

# %%
with open('test.json', 'w') as file:
    json.dump(data['cells'][-2]['outputs'][0]['data'], file)

# %%
data['cells'][-1]['outputs'][0]['data']
# Out:
# {'image/png': '...',
#  'text/plain': ['<Figure size 640x480 with 1 Axes>']}

# %%
print(''.join(data['cells'][-2]['source']))
# Out:
# fig = go.Figure()
#
# fig.add_trace(go.Scatter(
#     x=x,
#     y=y,
#     marker=dict(
#         color=y,
#         colorscale='oranges'
#     ),
#     mode='markers'
# ))
#
# fig.show()
